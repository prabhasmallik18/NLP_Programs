# %%
from nltk.util import ngrams
from collections import defaultdict

text = "Sachin and Virat were both well-known cricket players in India and people admired them for their hard work and steady performances."

words = text.split()

def print_ngrams(words):
    for n, title in [(1, "UNIGRAMS"), (2, "BIGRAMS"), (3, "TRIGRAMS"), (4, "4-GRAMS")]:
        print(f"\n{title}")
        for gram in ngrams(words, n):
            print(gram)

print_ngrams(words)

def highest_probability(text):
    words = text.split()
    bigram_counts = defaultdict(lambda: defaultdict(int))
    first_word_counts = defaultdict(int)

    for w1, w2 in zip(words, words[1:]):
        bigram_counts[w1][w2] += 1
        first_word_counts[w1] += 1

    result = {}
    for w1, followers in bigram_counts.items():
        best_w2, best_count = max(followers.items(), key=lambda x: x[1])
        result[w1] = (best_w2, best_count / first_word_counts[w1])

    return result

text2 = "Sachin and Virat played for India and both showed calm mindset and steady commitment during their careers."
output = highest_probability(text2)

print("\nHighest probabilities:")
for w1, (w2, prob) in output.items():
    print(f"After '{w1}' -> '{w2}' with probability {prob:.2f}")
# Out:
# UNIGRAMS
# ('Sachin',)
# ('and',)
# ('Virat',)
# ('were',)
# ('both',)
# ('well-known',)
# ('cricket',)
# ('players',)
# ('in',)
# ('India',)
# ('and',)
# ('people',)
# ('admired',)
# ('them',)
# ('for',)
# ('their',)
# ('hard',)
# ('work',)
# ('and',)
# ('steady',)
# ('performances.',)
#
# BIGRAMS
# ('Sachin', 'and')
# ('and', 'Virat')
# ('Virat', 'were')
# ('were', 'both')
# ('both', 'well-known')
# ('well-known', 'cricket')
# ('cricket', 'players')
# ('players', 'in')
# ('in', 'India')
# ('India', 'and')
# ('and', 'people')
# ('people', 'admired')
# ('admired', 'them')
# ('them', 'for')
# ('for', 'their')
# ('their', 'hard')
# ('hard', 'work')
# ('work', 'and')
# ('and', 'steady')
# ('steady', 'performances.')
#
# TRIGRAMS
# ('Sachin', 'and', 'Virat')
# ('and', 'Virat', 'were')
# ('Virat', 'were', 'both')
# ('were', 'both', 'well-known')
# ('both', 'well-known', 'cricket')
# ('well-known', 'cricket', 'players')
# ('cricket', 'players', 'in')
# ('players', 'in', 'India')
# ('in', 'India', 'and')
# ('India', 'and', 'people')
# ('and', 'people', 'admired')
# ('people', 'admired', 'them')
# ('admired', 'them', 'for')
# ('them', 'for', 'their')
# ('for', 'their', 'hard')
# ('their', 'hard', 'work')
# ('hard', 'work', 'and')
# ('work', 'and', 'steady')
# ('and', 'steady', 'performances.')
#
# 4-GRAMS
# ('Sachin', 'and', 'Virat', 'were')
# ('and', 'Virat', 'were', 'both')
# ('Virat', 'were', 'both', 'well-known')
# ('were', 'both', 'well-known', 'cricket')
# ('both', 'well-known', 'cricket', 'players')
# ('well-known', 'cricket', 'players', 'in')
# ('cricket', 'players', 'in', 'India')
# ('players', 'in', 'India', 'and')
# ('in', 'India', 'and', 'people')
# ('India', 'and', 'people', 'admired')
# ('and', 'people', 'admired', 'them')
# ('people', 'admired', 'them', 'for')
# ('admired', 'them', 'for', 'their')
# ('them', 'for', 'their', 'hard')
# ('for', 'their', 'hard', 'work')
# ('their', 'hard', 'work', 'and')
# ('hard', 'work', 'and', 'steady')
# ('work', 'and', 'steady', 'performances.')
#
# Highest probabilities:
# After 'Sachin' -> 'and' with probability 1.00
# After 'and' -> 'Virat' with probability 0.33
# After 'Virat' -> 'played' with probability 1.00
# After 'played' -> 'for' with probability 1.00
# After 'for' -> 'India' with probability 1.00
# After 'India' -> 'and' with probability 1.00
# After 'both' -> 'showed' with probability 1.00
# After 'showed' -> 'calm' with probability 1.00
# After 'calm' -> 'mindset' with probability 1.00
# After 'mindset' -> 'and' with probability 1.00
# After 'steady' -> 'commitment' with probability 1.00
# After 'commitment' -> 'during' with probability 1.00
# After 'during' -> 'their' with probability 1.00
# After 'their' -> 'careers.' with probability 1.00
